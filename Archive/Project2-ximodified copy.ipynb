# %% [markdown]
# # Yan-Ferrighetto Project 2

# %% [markdown]
# ### Part 1: Data Loading &amp; Preparation

# %% [markdown]
# 1.1 Load the data

# %%
# !pip install geopy
# !pip install imblearn
# Out:
# Requirement already satisfied: geopy in /Users/xiyan/.conda/envs/pythonPKG/lib/python3.9/site-packages (2.2.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /Users/xiyan/.conda/envs/pythonPKG/lib/python3.9/site-packages (from geopy) (1.52)
# Requirement already satisfied: imblearn in /Users/xiyan/.conda/envs/pythonPKG/lib/python3.9/site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in /Users/xiyan/.conda/envs/pythonPKG/lib/python3.9/site-packages (from imblearn) (0.9.0)
# Requirement already satisfied: scikit-learn>=1.0.1 in /Users/xiyan/.conda/envs/pythonPKG/lib/python3.9/site-packages (from imbalanced-learn->imblearn) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/xiyan/.conda/envs/pythonPKG/lib/python3.9/site-packages (from imbalanced-learn->imblearn) (3.1.0)
# Requirement already satisfied: numpy>=1.14.6 in /Users/xiyan/.conda/envs/pythonPKG/lib/python3.9/site-packages (from imbalanced-learn->imblearn) (1.22.3)
# Requirement already satisfied: joblib>=0.11 in /Users/xiyan/.conda/envs/pythonPKG/lib/python3.9/site-packages (from imbalanced-learn->imblearn) (1.1.0)
# Requirement already satisfied: scipy>=1.1.0 in /Users/xiyan/.conda/envs/pythonPKG/lib/python3.9/site-packages (from imbalanced-learn->imblearn) (1.8.0)

# %%
import glob
import pandas as pd
import numpy as np
import os

# %%
joined_files = os.path.join("./Source", "JC*.csv")
joined_list = glob.glob(joined_files)
pre_df = pd.concat(map(pd.read_csv, joined_list), ignore_index=True)
pre_df.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  74A4206E7487CBC9   docked_bike  2021-05-23 16:51:00  2021-05-23 18:38:21
# 1  58EEE2950FFE01CE   docked_bike  2021-05-31 16:54:47  2021-05-31 16:55:28
# 2  1429D912C16EEE59   docked_bike  2021-05-25 16:19:34  2021-05-25 17:03:06
# 3  FE9C5B74167CBCCD   docked_bike  2021-05-22 17:32:19  2021-05-22 17:41:27
# 4  B88D37626F000BBA   docked_bike  2021-05-14 09:48:34  2021-05-14 10:17:36
#
#               start_station_name start_station_id  \
# 0  9 St HBLR - Jackson St & 8 St            HB305
# 1  9 St HBLR - Jackson St & 8 St            HB305
# 2  9 St HBLR - Jackson St & 8 St            HB305
# 3  9 St HBLR - Jackson St & 8 St            HB305
# 4                       Union St            JC051
#
#                 end_station_name end_station_id  start_lat  start_lng  \
# 0  9 St HBLR - Jackson St & 8 St          HB305  40.747907 -74.038411
# 1  9 St HBLR - Jackson St & 8 St          HB305  40.747907 -74.038411
# 2  9 St HBLR - Jackson St & 8 St          HB305  40.747907 -74.038411
# 3                Grand St & 2 St          HB405  40.747907 -74.038411
# 4                     Newark Ave          JC032  40.718211 -74.083639
#
#      end_lat    end_lng member_casual
# 0  40.747907 -74.038412        casual
# 1  40.747907 -74.038412        member
# 2  40.747907 -74.038412        casual
# 3  40.739130 -74.036180        casual
# 4  40.721525 -74.046305        casual

# %%
pre_df.shape
# Out:
# (743074, 13)

# %%
"""
pre_df.dropna(inplace=True)
pre_df.shape
"""
# Out:
# '\npre_df.dropna(inplace=True)\npre_df.shape\n'

# %% [markdown]
# The NYC bikeshare data is from February of 2021 to March 2022. We originally planned on utilizing data beginning when the COVID-19 pandemic shutdowns began in the U.S. in March 2020, but unfortunately the data collected changed in January 2021, creating continuity issues. The dataset has 743,163 records and 13 columns.

# %% [markdown]
# 1.1 Preprocessing

# %%
pre_df = pre_df.drop(['ride_id', 'start_station_name', 'end_station_name'], 1)
pre_df.head()
# Out:
# /var/folders/ct/ty10q4_566jcj84rbd47bm7w0000gn/T/ipykernel_22648/4000247309.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   pre_df = pre_df.drop(['ride_id', 'start_station_name', 'end_station_name'], 1)
#   rideable_type           started_at             ended_at start_station_id  \
# 0   docked_bike  2021-05-23 16:51:00  2021-05-23 18:38:21            HB305
# 1   docked_bike  2021-05-31 16:54:47  2021-05-31 16:55:28            HB305
# 2   docked_bike  2021-05-25 16:19:34  2021-05-25 17:03:06            HB305
# 3   docked_bike  2021-05-22 17:32:19  2021-05-22 17:41:27            HB305
# 4   docked_bike  2021-05-14 09:48:34  2021-05-14 10:17:36            JC051
#
#   end_station_id  start_lat  start_lng    end_lat    end_lng member_casual
# 0          HB305  40.747907 -74.038411  40.747907 -74.038412        casual
# 1          HB305  40.747907 -74.038411  40.747907 -74.038412        member
# 2          HB305  40.747907 -74.038411  40.747907 -74.038412        casual
# 3          HB405  40.747907 -74.038411  40.739130 -74.036180        casual
# 4          JC032  40.718211 -74.083639  40.721525 -74.046305        casual

# %% [markdown]
# Add feature for ZipCode and City

# %%
a = pd.read_csv('./Source/out.csv')
a['ZipCode'] = a['address'].str[:5].astype(int)
a
# Out:
#      Unnamed: 0        lat        lng address  ZipCode
# 0             1  40.721630 -74.049967   07302     7302
# 1             2  40.749984 -74.027150   07030     7030
# 2             3  40.745983 -74.028199   07030     7030
# 3            12  40.721630 -74.049968   07302     7302
# 4            28  40.745984 -74.028199   07030     7030
# ..          ...        ...        ...     ...      ...
# 430      714140  40.752271 -73.987706   10018    10018
# 431      723276  40.801343 -73.971146   10025    10025
# 432      724586  40.861560 -73.912190   10468    10468
# 433      736040  40.705945 -74.013219   10006    10006
# 434      741191  40.704633 -74.013617   10275    10275
#
# [435 rows x 5 columns]

# %%
ny = pd.read_csv('./Source/nyc-zip-codes.csv')
ny['City'] = ny['Borough']
nj = pd.read_csv('./Source/nj-zip-codes.csv')
zip_city = pd.concat([ny, nj])
zip_city = zip_city[['ZipCode', 'City']]
zip_city
# Out:
#      ZipCode          City
# 0      10453         Bronx
# 1      10457         Bronx
# 2      10460         Bronx
# 3      10458         Bronx
# 4      10467         Bronx
# ..       ...           ...
# 166     7036        Linden
# 167     7065        Rahway
# 168     7203       Roselle
# 169     7204  Roselle Park
# 170     7083         Union
#
# [368 rows x 2 columns]

# %%
b = pd.merge(a, zip_city, how='left', on='ZipCode')
b = b[['lat', 'lng', 'ZipCode', 'City']]
b
# Out:
#            lat        lng  ZipCode         City
# 0    40.721630 -74.049967     7302  Jersey City
# 1    40.749984 -74.027150     7030      Hoboken
# 2    40.745983 -74.028199     7030      Hoboken
# 3    40.721630 -74.049968     7302  Jersey City
# 4    40.745984 -74.028199     7030      Hoboken
# ..         ...        ...      ...          ...
# 433  40.752271 -73.987706    10018    Manhattan
# 434  40.801343 -73.971146    10025    Manhattan
# 435  40.861560 -73.912190    10468        Bronx
# 436  40.705945 -74.013219    10006    Manhattan
# 437  40.704633 -74.013617    10275    Manhattan
#
# [438 rows x 4 columns]

# %%
pre_df = pre_df.merge(b, how='left', left_on=['start_lat', 'start_lng'], right_on=['lat', 'lng'])

# %%
pre_df['start_zip'] = pre_df['ZipCode']
pre_df['start_city'] = pre_df['City']
pre_df = pre_df.drop(['lat','lng','ZipCode','City'], axis=1)

# %%
pre_df = pre_df.merge(b, how='left', left_on=['end_lat', 'end_lng'], right_on=['lat', 'lng'])

# %%
pre_df['end_zip'] = pre_df['ZipCode']
pre_df['end_city'] = pre_df['City']
pre_df = pre_df.drop(['lat','lng','ZipCode','City'], axis=1)

# %%
pre_df
# Out:
#        rideable_type           started_at             ended_at  \
# 0        docked_bike  2021-05-23 16:51:00  2021-05-23 18:38:21
# 1        docked_bike  2021-05-31 16:54:47  2021-05-31 16:55:28
# 2        docked_bike  2021-05-25 16:19:34  2021-05-25 17:03:06
# 3        docked_bike  2021-05-22 17:32:19  2021-05-22 17:41:27
# 4        docked_bike  2021-05-14 09:48:34  2021-05-14 10:17:36
# ...              ...                  ...                  ...
# 743076   docked_bike  2021-02-24 18:05:45  2021-02-24 18:12:27
# 743077   docked_bike  2021-02-22 18:22:04  2021-02-22 18:28:45
# 743078   docked_bike  2021-02-13 12:21:49  2021-02-13 12:27:51
# 743079   docked_bike  2021-02-25 11:20:29  2021-02-25 11:25:23
# 743080   docked_bike  2021-02-19 13:59:22  2021-02-19 14:05:47
#
#        start_station_id end_station_id  start_lat  start_lng    end_lat  \
# 0                 HB305          HB305  40.747907 -74.038411  40.747907
# 1                 HB305          HB305  40.747907 -74.038411  40.747907
# 2                 HB305          HB305  40.747907 -74.038411  40.747907
# 3                 HB305          HB405  40.747907 -74.038411  40.739130
# 4                 JC051          JC032  40.718211 -74.083639  40.721525
# ...                 ...            ...        ...        ...        ...
# 743076            JC014          JC008  40.718355 -74.038914  40.728745
# 743077            JC014          JC008  40.718355 -74.038914  40.728745
# 743078            JC014          JC008  40.718355 -74.038914  40.728745
# 743079            JC014          JC072  40.718355 -74.038914  40.712419
# 743080            JC014          JC008  40.718355 -74.038914  40.728745
#
#           end_lng member_casual  start_zip   start_city  end_zip     end_city
# 0      -74.038412        casual       7030      Hoboken   7030.0      Hoboken
# 1      -74.038412        member       7030      Hoboken   7030.0      Hoboken
# 2      -74.038412        casual       7030      Hoboken   7030.0      Hoboken
# 3      -74.036180        casual       7030      Hoboken   7030.0      Hoboken
# 4      -74.046305        casual       7304  Jersey City   7302.0  Jersey City
# ...           ...           ...        ...          ...      ...          ...
# 743076 -74.032108        member       7302  Jersey City   7310.0  Jersey City
# 743077 -74.032108        member       7302  Jersey City   7310.0  Jersey City
# 743078 -74.032108        member       7302  Jersey City   7310.0  Jersey City
# 743079 -74.038526        member       7302  Jersey City   7302.0  Jersey City
# 743080 -74.032108        member       7302  Jersey City   7310.0  Jersey City
#
# [743081 rows x 14 columns]

# %% [markdown]
# Distance

# %%
pre_df[pre_df['end_lat'].isnull()]
# Out:
#        rideable_type           started_at             ended_at  \
# 5547     docked_bike  2021-05-28 00:18:55  2021-05-29 01:18:49
# 5587     docked_bike  2021-05-27 22:00:08  2021-05-28 23:00:04
# 5590     docked_bike  2021-05-27 19:09:47  2021-05-28 20:09:41
# 5591     docked_bike  2021-05-27 22:00:28  2021-05-28 23:00:23
# 5593     docked_bike  2021-05-08 00:22:05  2021-05-09 01:22:00
# ...              ...                  ...                  ...
# 742743   docked_bike  2021-02-16 17:39:55  2021-02-16 17:54:53
# 742804   docked_bike  2021-02-12 14:24:38  2021-02-13 15:24:32
# 742810   docked_bike  2021-02-16 18:51:33  2021-02-16 20:49:07
# 742870   docked_bike  2021-02-09 05:48:18  2021-02-09 07:22:41
# 742940   docked_bike  2021-02-08 08:53:53  2021-02-08 13:03:06
#
#        start_station_id end_station_id  start_lat  start_lng  end_lat  \
# 5547              JC063            NaN  40.711130 -74.078900      NaN
# 5587              JC084            NaN  40.714358 -74.066610      NaN
# 5590              JC084            NaN  40.714358 -74.066610      NaN
# 5591              JC084            NaN  40.714358 -74.066610      NaN
# 5593              JC082            NaN  40.721650 -74.042884      NaN
# ...                 ...            ...        ...        ...      ...
# 742743            JC003            NaN  40.717732 -74.043845      NaN
# 742804            JC003            NaN  40.717732 -74.043845      NaN
# 742810            JC027            NaN  40.725289 -74.045571      NaN
# 742870            JC027            NaN  40.725289 -74.045571      NaN
# 742940            JC027            NaN  40.725289 -74.045571      NaN
#
#         end_lng member_casual  start_zip   start_city  end_zip end_city
# 5547        NaN        casual       7305  Jersey City      NaN      NaN
# 5587        NaN        casual       7304  Jersey City      NaN      NaN
# 5590        NaN        casual       7304  Jersey City      NaN      NaN
# 5591        NaN        casual       7304  Jersey City      NaN      NaN
# 5593        NaN        casual       7302  Jersey City      NaN      NaN
# ...         ...           ...        ...          ...      ...      ...
# 742743      NaN        member       7302  Jersey City      NaN      NaN
# 742804      NaN        casual       7302  Jersey City      NaN      NaN
# 742810      NaN        member       7302  Jersey City      NaN      NaN
# 742870      NaN        member       7302  Jersey City      NaN      NaN
# 742940      NaN        member       7302  Jersey City      NaN      NaN
#
# [2481 rows x 14 columns]

# %%
from geopy import distance

def cal_distance(from_lat, from_lng, to_lat, to_lng):
    go = (from_lat, from_lng)
    to = (to_lat, to_lng)
    try:
        return distance.great_circle(go, to)
    except ValueError:
        return np.nan

pre_df['distance'] = pre_df.apply(lambda row: cal_distance(row.start_lat,row.start_lng, row.end_lat, row.end_lng), axis=1)

# %%
pre_df[pre_df['end_lat'].isnull()]
# Out:
#        rideable_type           started_at             ended_at  \
# 5547     docked_bike  2021-05-28 00:18:55  2021-05-29 01:18:49
# 5587     docked_bike  2021-05-27 22:00:08  2021-05-28 23:00:04
# 5590     docked_bike  2021-05-27 19:09:47  2021-05-28 20:09:41
# 5591     docked_bike  2021-05-27 22:00:28  2021-05-28 23:00:23
# 5593     docked_bike  2021-05-08 00:22:05  2021-05-09 01:22:00
# ...              ...                  ...                  ...
# 742743   docked_bike  2021-02-16 17:39:55  2021-02-16 17:54:53
# 742804   docked_bike  2021-02-12 14:24:38  2021-02-13 15:24:32
# 742810   docked_bike  2021-02-16 18:51:33  2021-02-16 20:49:07
# 742870   docked_bike  2021-02-09 05:48:18  2021-02-09 07:22:41
# 742940   docked_bike  2021-02-08 08:53:53  2021-02-08 13:03:06
#
#        start_station_id end_station_id  start_lat  start_lng  end_lat  \
# 5547              JC063            NaN  40.711130 -74.078900      NaN
# 5587              JC084            NaN  40.714358 -74.066610      NaN
# 5590              JC084            NaN  40.714358 -74.066610      NaN
# 5591              JC084            NaN  40.714358 -74.066610      NaN
# 5593              JC082            NaN  40.721650 -74.042884      NaN
# ...                 ...            ...        ...        ...      ...
# 742743            JC003            NaN  40.717732 -74.043845      NaN
# 742804            JC003            NaN  40.717732 -74.043845      NaN
# 742810            JC027            NaN  40.725289 -74.045571      NaN
# 742870            JC027            NaN  40.725289 -74.045571      NaN
# 742940            JC027            NaN  40.725289 -74.045571      NaN
#
#         end_lng member_casual  start_zip   start_city  end_zip end_city  \
# 5547        NaN        casual       7305  Jersey City      NaN      NaN
# 5587        NaN        casual       7304  Jersey City      NaN      NaN
# 5590        NaN        casual       7304  Jersey City      NaN      NaN
# 5591        NaN        casual       7304  Jersey City      NaN      NaN
# 5593        NaN        casual       7302  Jersey City      NaN      NaN
# ...         ...           ...        ...          ...      ...      ...
# 742743      NaN        member       7302  Jersey City      NaN      NaN
# 742804      NaN        casual       7302  Jersey City      NaN      NaN
# 742810      NaN        member       7302  Jersey City      NaN      NaN
# 742870      NaN        member       7302  Jersey City      NaN      NaN
# 742940      NaN        member       7302  Jersey City      NaN      NaN
#
#        distance
# 5547        NaN
# 5587        NaN
# 5590        NaN
# 5591        NaN
# 5593        NaN
# ...         ...
# 742743      NaN
# 742804      NaN
# 742810      NaN
# 742870      NaN
# 742940      NaN
#
# [2481 rows x 15 columns]

# %%
pre_df['distance'] = pre_df['distance'].astype(str).str[:-3].astype('float64', errors = 'ignore')

# %%
pre_df[pre_df['end_lat'].isnull()]
# Out:
#        rideable_type           started_at             ended_at  \
# 5547     docked_bike  2021-05-28 00:18:55  2021-05-29 01:18:49
# 5587     docked_bike  2021-05-27 22:00:08  2021-05-28 23:00:04
# 5590     docked_bike  2021-05-27 19:09:47  2021-05-28 20:09:41
# 5591     docked_bike  2021-05-27 22:00:28  2021-05-28 23:00:23
# 5593     docked_bike  2021-05-08 00:22:05  2021-05-09 01:22:00
# ...              ...                  ...                  ...
# 742743   docked_bike  2021-02-16 17:39:55  2021-02-16 17:54:53
# 742804   docked_bike  2021-02-12 14:24:38  2021-02-13 15:24:32
# 742810   docked_bike  2021-02-16 18:51:33  2021-02-16 20:49:07
# 742870   docked_bike  2021-02-09 05:48:18  2021-02-09 07:22:41
# 742940   docked_bike  2021-02-08 08:53:53  2021-02-08 13:03:06
#
#        start_station_id end_station_id  start_lat  start_lng  end_lat  \
# 5547              JC063            NaN  40.711130 -74.078900      NaN
# 5587              JC084            NaN  40.714358 -74.066610      NaN
# 5590              JC084            NaN  40.714358 -74.066610      NaN
# 5591              JC084            NaN  40.714358 -74.066610      NaN
# 5593              JC082            NaN  40.721650 -74.042884      NaN
# ...                 ...            ...        ...        ...      ...
# 742743            JC003            NaN  40.717732 -74.043845      NaN
# 742804            JC003            NaN  40.717732 -74.043845      NaN
# 742810            JC027            NaN  40.725289 -74.045571      NaN
# 742870            JC027            NaN  40.725289 -74.045571      NaN
# 742940            JC027            NaN  40.725289 -74.045571      NaN
#
#         end_lng member_casual  start_zip   start_city  end_zip end_city  \
# 5547        NaN        casual       7305  Jersey City      NaN      NaN
# 5587        NaN        casual       7304  Jersey City      NaN      NaN
# 5590        NaN        casual       7304  Jersey City      NaN      NaN
# 5591        NaN        casual       7304  Jersey City      NaN      NaN
# 5593        NaN        casual       7302  Jersey City      NaN      NaN
# ...         ...           ...        ...          ...      ...      ...
# 742743      NaN        member       7302  Jersey City      NaN      NaN
# 742804      NaN        casual       7302  Jersey City      NaN      NaN
# 742810      NaN        member       7302  Jersey City      NaN      NaN
# 742870      NaN        member       7302  Jersey City      NaN      NaN
# 742940      NaN        member       7302  Jersey City      NaN      NaN
#
#        distance
# 5547
# 5587
# 5590
# 5591
# 5593
# ...         ...
# 742743
# 742804
# 742810
# 742870
# 742940
#
# [2481 rows x 15 columns]

# %%
pre_df['distance'] = pre_df['distance'].fillna(0)

# %%
pre_df[pre_df['end_lat'].isnull()]
# Out:
#        rideable_type           started_at             ended_at  \
# 5547     docked_bike  2021-05-28 00:18:55  2021-05-29 01:18:49
# 5587     docked_bike  2021-05-27 22:00:08  2021-05-28 23:00:04
# 5590     docked_bike  2021-05-27 19:09:47  2021-05-28 20:09:41
# 5591     docked_bike  2021-05-27 22:00:28  2021-05-28 23:00:23
# 5593     docked_bike  2021-05-08 00:22:05  2021-05-09 01:22:00
# ...              ...                  ...                  ...
# 742743   docked_bike  2021-02-16 17:39:55  2021-02-16 17:54:53
# 742804   docked_bike  2021-02-12 14:24:38  2021-02-13 15:24:32
# 742810   docked_bike  2021-02-16 18:51:33  2021-02-16 20:49:07
# 742870   docked_bike  2021-02-09 05:48:18  2021-02-09 07:22:41
# 742940   docked_bike  2021-02-08 08:53:53  2021-02-08 13:03:06
#
#        start_station_id end_station_id  start_lat  start_lng  end_lat  \
# 5547              JC063            NaN  40.711130 -74.078900      NaN
# 5587              JC084            NaN  40.714358 -74.066610      NaN
# 5590              JC084            NaN  40.714358 -74.066610      NaN
# 5591              JC084            NaN  40.714358 -74.066610      NaN
# 5593              JC082            NaN  40.721650 -74.042884      NaN
# ...                 ...            ...        ...        ...      ...
# 742743            JC003            NaN  40.717732 -74.043845      NaN
# 742804            JC003            NaN  40.717732 -74.043845      NaN
# 742810            JC027            NaN  40.725289 -74.045571      NaN
# 742870            JC027            NaN  40.725289 -74.045571      NaN
# 742940            JC027            NaN  40.725289 -74.045571      NaN
#
#         end_lng member_casual  start_zip   start_city  end_zip end_city  \
# 5547        NaN        casual       7305  Jersey City      NaN      NaN
# 5587        NaN        casual       7304  Jersey City      NaN      NaN
# 5590        NaN        casual       7304  Jersey City      NaN      NaN
# 5591        NaN        casual       7304  Jersey City      NaN      NaN
# 5593        NaN        casual       7302  Jersey City      NaN      NaN
# ...         ...           ...        ...          ...      ...      ...
# 742743      NaN        member       7302  Jersey City      NaN      NaN
# 742804      NaN        casual       7302  Jersey City      NaN      NaN
# 742810      NaN        member       7302  Jersey City      NaN      NaN
# 742870      NaN        member       7302  Jersey City      NaN      NaN
# 742940      NaN        member       7302  Jersey City      NaN      NaN
#
#        distance
# 5547
# 5587
# 5590
# 5591
# 5593
# ...         ...
# 742743
# 742804
# 742810
# 742870
# 742940
#
# [2481 rows x 15 columns]

# %% [markdown]
# Drop weird ridetype

# %%
pre_df['rideable_type'].value_counts()
# Out:
# classic_bike              582589
# docked_bike               141306
# electric_bike              19185
# motivate_dockless_bike         1
# Name: rideable_type, dtype: int64

# %%
pre_df = pre_df[(pre_df.rideable_type != 'motivate_dockless_bike')]

# %% [markdown]
# Add feature - Intra city

# %%
import numpy as np
pre_df['intra'] = np.where(pre_df['start_city']!=pre_df['end_city'], 1, 0)
# Out:
# /var/folders/ct/ty10q4_566jcj84rbd47bm7w0000gn/T/ipykernel_22648/4089713024.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pre_df['intra'] = np.where(pre_df['start_city']!=pre_df['end_city'], 1, 0)

# %%
pre_df
# Out:
#        rideable_type           started_at             ended_at  \
# 0        docked_bike  2021-05-23 16:51:00  2021-05-23 18:38:21
# 1        docked_bike  2021-05-31 16:54:47  2021-05-31 16:55:28
# 2        docked_bike  2021-05-25 16:19:34  2021-05-25 17:03:06
# 3        docked_bike  2021-05-22 17:32:19  2021-05-22 17:41:27
# 4        docked_bike  2021-05-14 09:48:34  2021-05-14 10:17:36
# ...              ...                  ...                  ...
# 743076   docked_bike  2021-02-24 18:05:45  2021-02-24 18:12:27
# 743077   docked_bike  2021-02-22 18:22:04  2021-02-22 18:28:45
# 743078   docked_bike  2021-02-13 12:21:49  2021-02-13 12:27:51
# 743079   docked_bike  2021-02-25 11:20:29  2021-02-25 11:25:23
# 743080   docked_bike  2021-02-19 13:59:22  2021-02-19 14:05:47
#
#        start_station_id end_station_id  start_lat  start_lng    end_lat  \
# 0                 HB305          HB305  40.747907 -74.038411  40.747907
# 1                 HB305          HB305  40.747907 -74.038411  40.747907
# 2                 HB305          HB305  40.747907 -74.038411  40.747907
# 3                 HB305          HB405  40.747907 -74.038411  40.739130
# 4                 JC051          JC032  40.718211 -74.083639  40.721525
# ...                 ...            ...        ...        ...        ...
# 743076            JC014          JC008  40.718355 -74.038914  40.728745
# 743077            JC014          JC008  40.718355 -74.038914  40.728745
# 743078            JC014          JC008  40.718355 -74.038914  40.728745
# 743079            JC014          JC072  40.718355 -74.038914  40.712419
# 743080            JC014          JC008  40.718355 -74.038914  40.728745
#
#           end_lng member_casual  start_zip   start_city  end_zip     end_city  \
# 0      -74.038412        casual       7030      Hoboken   7030.0      Hoboken
# 1      -74.038412        member       7030      Hoboken   7030.0      Hoboken
# 2      -74.038412        casual       7030      Hoboken   7030.0      Hoboken
# 3      -74.036180        casual       7030      Hoboken   7030.0      Hoboken
# 4      -74.046305        casual       7304  Jersey City   7302.0  Jersey City
# ...           ...           ...        ...          ...      ...          ...
# 743076 -74.032108        member       7302  Jersey City   7310.0  Jersey City
# 743077 -74.032108        member       7302  Jersey City   7310.0  Jersey City
# 743078 -74.032108        member       7302  Jersey City   7310.0  Jersey City
# 743079 -74.038526        member       7302  Jersey City   7302.0  Jersey City
# 743080 -74.032108        member       7302  Jersey City   7310.0  Jersey City
#
#                      distance  intra
# 0       5.021014915867473e-05      0
# 1       5.021014915867473e-05      0
# 2       5.021014915867473e-05      0
# 3          0.9938925900796551      0
# 4          3.1678936428785565      0
# ...                       ...    ...
# 743076       1.28982334621709      0
# 743077       1.28982334621709      0
# 743078       1.28982334621709      0
# 743079       0.66088514879881      0
# 743080       1.28982334621709      0
#
# [743080 rows x 16 columns]

# %% [markdown]
# Start at end at

# %%
pre_df[["started_at", "ended_at"]] = pre_df[["started_at", "ended_at"]].apply(pd.to_datetime)
# Out:
# /var/folders/ct/ty10q4_566jcj84rbd47bm7w0000gn/T/ipykernel_22648/1824175102.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pre_df[["started_at", "ended_at"]] = pre_df[["started_at", "ended_at"]].apply(pd.to_datetime)

# %%
pre_df['duration'] = pre_df['ended_at']-pre_df['started_at']
# Out:
# /var/folders/ct/ty10q4_566jcj84rbd47bm7w0000gn/T/ipykernel_22648/2800600990.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pre_df['duration'] = pre_df['ended_at']-pre_df['started_at']

# %%
pre_df['duration_secs'] = pre_df['duration'].dt.total_seconds()
# Out:
# /var/folders/ct/ty10q4_566jcj84rbd47bm7w0000gn/T/ipykernel_22648/3474685209.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pre_df['duration_secs'] = pre_df['duration'].dt.total_seconds()

# %%
import numpy as np
#Time of day and season are calculated using started_at derived values
[month%12 // 3 + 1 for month in range(1, 13)]
pre_df['season_num'] = pre_df['started_at'].dt.month%12 // 3 + 1
#pre_df['season'] = pre_df['season_num'].map({1:'Winter',2:'Spring', 3: 'Summer', 4: 'Fall'})
#pre_df['season'] = pre_df['season'].astype("string")
# Out:
# /var/folders/ct/ty10q4_566jcj84rbd47bm7w0000gn/T/ipykernel_22648/4137525598.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pre_df['season_num'] = pre_df['started_at'].dt.month%12 // 3 + 1

# %%
#Time of day and season are calculated using started_at derived values
pre_df['time_of_day'] = (pre_df['started_at'].dt.hour % 24 + 4) // 4
pre_df['time_of_day'].replace({1: 'Late Night',
                      2: 'Early Morning',
                      3: 'Morning',
                      4: 'Noon',
                      5: 'Evening',
                      6: 'Night'}, inplace=True)
# Out:
# /var/folders/ct/ty10q4_566jcj84rbd47bm7w0000gn/T/ipykernel_22648/2279579729.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pre_df['time_of_day'] = (pre_df['started_at'].dt.hour % 24 + 4) // 4
# /var/folders/ct/ty10q4_566jcj84rbd47bm7w0000gn/T/ipykernel_22648/2279579729.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pre_df['time_of_day'].replace({1: 'Late Night',

# %%
pre_df
# Out:
#        rideable_type          started_at            ended_at start_station_id  \
# 0        docked_bike 2021-05-23 16:51:00 2021-05-23 18:38:21            HB305
# 1        docked_bike 2021-05-31 16:54:47 2021-05-31 16:55:28            HB305
# 2        docked_bike 2021-05-25 16:19:34 2021-05-25 17:03:06            HB305
# 3        docked_bike 2021-05-22 17:32:19 2021-05-22 17:41:27            HB305
# 4        docked_bike 2021-05-14 09:48:34 2021-05-14 10:17:36            JC051
# ...              ...                 ...                 ...              ...
# 743076   docked_bike 2021-02-24 18:05:45 2021-02-24 18:12:27            JC014
# 743077   docked_bike 2021-02-22 18:22:04 2021-02-22 18:28:45            JC014
# 743078   docked_bike 2021-02-13 12:21:49 2021-02-13 12:27:51            JC014
# 743079   docked_bike 2021-02-25 11:20:29 2021-02-25 11:25:23            JC014
# 743080   docked_bike 2021-02-19 13:59:22 2021-02-19 14:05:47            JC014
#
#        end_station_id  start_lat  start_lng    end_lat    end_lng  \
# 0               HB305  40.747907 -74.038411  40.747907 -74.038412
# 1               HB305  40.747907 -74.038411  40.747907 -74.038412
# 2               HB305  40.747907 -74.038411  40.747907 -74.038412
# 3               HB405  40.747907 -74.038411  40.739130 -74.036180
# 4               JC032  40.718211 -74.083639  40.721525 -74.046305
# ...               ...        ...        ...        ...        ...
# 743076          JC008  40.718355 -74.038914  40.728745 -74.032108
# 743077          JC008  40.718355 -74.038914  40.728745 -74.032108
# 743078          JC008  40.718355 -74.038914  40.728745 -74.032108
# 743079          JC072  40.718355 -74.038914  40.712419 -74.038526
# 743080          JC008  40.718355 -74.038914  40.728745 -74.032108
#
#        member_casual  start_zip   start_city  end_zip     end_city  \
# 0             casual       7030      Hoboken   7030.0      Hoboken
# 1             member       7030      Hoboken   7030.0      Hoboken
# 2             casual       7030      Hoboken   7030.0      Hoboken
# 3             casual       7030      Hoboken   7030.0      Hoboken
# 4             casual       7304  Jersey City   7302.0  Jersey City
# ...              ...        ...          ...      ...          ...
# 743076        member       7302  Jersey City   7310.0  Jersey City
# 743077        member       7302  Jersey City   7310.0  Jersey City
# 743078        member       7302  Jersey City   7310.0  Jersey City
# 743079        member       7302  Jersey City   7302.0  Jersey City
# 743080        member       7302  Jersey City   7310.0  Jersey City
#
#                      distance  intra        duration  duration_secs  \
# 0       5.021014915867473e-05      0 0 days 01:47:21         6441.0
# 1       5.021014915867473e-05      0 0 days 00:00:41           41.0
# 2       5.021014915867473e-05      0 0 days 00:43:32         2612.0
# 3          0.9938925900796551      0 0 days 00:09:08          548.0
# 4          3.1678936428785565      0 0 days 00:29:02         1742.0
# ...                       ...    ...             ...            ...
# 743076       1.28982334621709      0 0 days 00:06:42          402.0
# 743077       1.28982334621709      0 0 days 00:06:41          401.0
# 743078       1.28982334621709      0 0 days 00:06:02          362.0
# 743079       0.66088514879881      0 0 days 00:04:54          294.0
# 743080       1.28982334621709      0 0 days 00:06:25          385.0
#
#         season_num time_of_day
# 0                2     Evening
# 1                2     Evening
# 2                2     Evening
# 3                2     Evening
# 4                2     Morning
# ...            ...         ...
# 743076           1     Evening
# 743077           1     Evening
# 743078           1        Noon
# 743079           1     Morning
# 743080           1        Noon
#
# [743080 rows x 20 columns]

# %%
pre_df[pre_df['end_lat'].isnull()]
# Out:
#        rideable_type          started_at            ended_at start_station_id  \
# 5547     docked_bike 2021-05-28 00:18:55 2021-05-29 01:18:49            JC063
# 5587     docked_bike 2021-05-27 22:00:08 2021-05-28 23:00:04            JC084
# 5590     docked_bike 2021-05-27 19:09:47 2021-05-28 20:09:41            JC084
# 5591     docked_bike 2021-05-27 22:00:28 2021-05-28 23:00:23            JC084
# 5593     docked_bike 2021-05-08 00:22:05 2021-05-09 01:22:00            JC082
# ...              ...                 ...                 ...              ...
# 742743   docked_bike 2021-02-16 17:39:55 2021-02-16 17:54:53            JC003
# 742804   docked_bike 2021-02-12 14:24:38 2021-02-13 15:24:32            JC003
# 742810   docked_bike 2021-02-16 18:51:33 2021-02-16 20:49:07            JC027
# 742870   docked_bike 2021-02-09 05:48:18 2021-02-09 07:22:41            JC027
# 742940   docked_bike 2021-02-08 08:53:53 2021-02-08 13:03:06            JC027
#
#        end_station_id  start_lat  start_lng  end_lat  end_lng member_casual  \
# 5547              NaN  40.711130 -74.078900      NaN      NaN        casual
# 5587              NaN  40.714358 -74.066610      NaN      NaN        casual
# 5590              NaN  40.714358 -74.066610      NaN      NaN        casual
# 5591              NaN  40.714358 -74.066610      NaN      NaN        casual
# 5593              NaN  40.721650 -74.042884      NaN      NaN        casual
# ...               ...        ...        ...      ...      ...           ...
# 742743            NaN  40.717732 -74.043845      NaN      NaN        member
# 742804            NaN  40.717732 -74.043845      NaN      NaN        casual
# 742810            NaN  40.725289 -74.045571      NaN      NaN        member
# 742870            NaN  40.725289 -74.045571      NaN      NaN        member
# 742940            NaN  40.725289 -74.045571      NaN      NaN        member
#
#         start_zip   start_city  end_zip end_city distance  intra  \
# 5547         7305  Jersey City      NaN      NaN               1
# 5587         7304  Jersey City      NaN      NaN               1
# 5590         7304  Jersey City      NaN      NaN               1
# 5591         7304  Jersey City      NaN      NaN               1
# 5593         7302  Jersey City      NaN      NaN               1
# ...           ...          ...      ...      ...      ...    ...
# 742743       7302  Jersey City      NaN      NaN               1
# 742804       7302  Jersey City      NaN      NaN               1
# 742810       7302  Jersey City      NaN      NaN               1
# 742870       7302  Jersey City      NaN      NaN               1
# 742940       7302  Jersey City      NaN      NaN               1
#
#               duration  duration_secs  season_num    time_of_day
# 5547   1 days 00:59:54        89994.0           2     Late Night
# 5587   1 days 00:59:56        89996.0           2          Night
# 5590   1 days 00:59:54        89994.0           2        Evening
# 5591   1 days 00:59:55        89995.0           2          Night
# 5593   1 days 00:59:55        89995.0           2     Late Night
# ...                ...            ...         ...            ...
# 742743 0 days 00:14:58          898.0           1        Evening
# 742804 1 days 00:59:54        89994.0           1           Noon
# 742810 0 days 01:57:34         7054.0           1        Evening
# 742870 0 days 01:34:23         5663.0           1  Early Morning
# 742940 0 days 04:09:13        14953.0           1        Morning
#
# [2481 rows x 20 columns]

# %% [markdown]
# # Part 2

# %% [markdown]
# ### Data Cleaning

# %%
pre_df_p2 = pre_df

# %%
pre_df_p2 = pre_df_p2.drop(['duration', 'started_at', 'ended_at', 'start_lat', 'start_lng', 'end_lat', 'end_lng', 'start_zip', 'end_zip', 'end_station_id', 'end_city', 'start_city'], axis=1)

# %%
pre_df_p2['distance'] = pre_df_p2['distance'].replace('', np.NAN)
pre_df_p2[pre_df_p2['distance'].isnull()]
# Out:
#        rideable_type start_station_id member_casual distance  intra  \
# 5547     docked_bike            JC063        casual      NaN      1
# 5587     docked_bike            JC084        casual      NaN      1
# 5590     docked_bike            JC084        casual      NaN      1
# 5591     docked_bike            JC084        casual      NaN      1
# 5593     docked_bike            JC082        casual      NaN      1
# ...              ...              ...           ...      ...    ...
# 742743   docked_bike            JC003        member      NaN      1
# 742804   docked_bike            JC003        casual      NaN      1
# 742810   docked_bike            JC027        member      NaN      1
# 742870   docked_bike            JC027        member      NaN      1
# 742940   docked_bike            JC027        member      NaN      1
#
#         duration_secs  season_num    time_of_day
# 5547          89994.0           2     Late Night
# 5587          89996.0           2          Night
# 5590          89994.0           2        Evening
# 5591          89995.0           2          Night
# 5593          89995.0           2     Late Night
# ...               ...         ...            ...
# 742743          898.0           1        Evening
# 742804        89994.0           1           Noon
# 742810         7054.0           1        Evening
# 742870         5663.0           1  Early Morning
# 742940        14953.0           1        Morning
#
# [2481 rows x 8 columns]

# %%
from sklearn.preprocessing import LabelEncoder

non_numeric_cols = ['member_casual', 'time_of_day', 'rideable_type', 'start_station_id']
for col in non_numeric_cols:
    pre_df_p2[col] = LabelEncoder().fit_transform(pre_df_p2[col].values)

pre_df_p2
# Out:
#         rideable_type  start_station_id  member_casual               distance  \
# 0                   1                12              0  5.021014915867473e-05
# 1                   1                12              1  5.021014915867473e-05
# 2                   1                12              0  5.021014915867473e-05
# 3                   1                12              0     0.9938925900796551
# 4                   1                51              0     3.1678936428785565
# ...               ...               ...            ...                    ...
# 743076              1                39              1       1.28982334621709
# 743077              1                39              1       1.28982334621709
# 743078              1                39              1       1.28982334621709
# 743079              1                39              1       0.66088514879881
# 743080              1                39              1       1.28982334621709
#
#         intra  duration_secs  season_num  time_of_day
# 0           0         6441.0           2            1
# 1           0           41.0           2            1
# 2           0         2612.0           2            1
# 3           0          548.0           2            1
# 4           0         1742.0           2            3
# ...       ...            ...         ...          ...
# 743076      0          402.0           1            1
# 743077      0          401.0           1            1
# 743078      0          362.0           1            5
# 743079      0          294.0           1            3
# 743080      0          385.0           1            5
#
# [743080 rows x 8 columns]

# %% [markdown]
# Split train test dataset

# %%
from sklearn.model_selection import train_test_split
train_set_p2, test_set_p2 = train_test_split(pre_df_p2, test_size=0.2, random_state=35)

# %% [markdown]
# ## In train dataset:

# %% [markdown]
# Drop Unuseful features

# %% [markdown]
# Drop duplicates

# %%
dups = train_set_p2.duplicated()
train_set_p2[dups]
# Out:
#         rideable_type  start_station_id  member_casual             distance  \
# 395741              1                34              1   0.6470440688819047
# 294569              0                46              1   0.6670196269168461
# 567285              0                27              0    0.976675801683034
# 261482              0                64              1   0.6204420455380038
# 290580              0                60              1   0.7686893564668077
# ...               ...               ...            ...                  ...
# 282413              0                54              1   0.6924918349345762
# 643007              0                65              1  0.31416832462829586
# 29053               1                35              1   0.5707006757143257
# 361768              0                29              1  0.43247977514785535
# 512201              0                75              1   0.5707694065776155
#
#         intra  duration_secs  season_num  time_of_day
# 395741      0          188.0           2            3
# 294569      0          237.0           4            3
# 567285      0          357.0           4            1
# 261482      0          180.0           3            0
# 290580      0          296.0           4            1
# ...       ...            ...         ...          ...
# 282413      0          211.0           4            1
# 643007      0          120.0           4            5
# 29053       0          303.0           2            1
# 361768      0          152.0           4            5
# 512201      0          168.0           3            1
#
# [22139 rows x 8 columns]

# %%
train_set_p2.drop_duplicates(inplace=True)

# %% [markdown]
# Check if there are any null values (should not have any since we drop them during pre-process part)

# %%
train_set_p2.isnull().sum()
# Out:
# rideable_type          0
# start_station_id       0
# member_casual          0
# distance            1877
# intra                  0
# duration_secs          0
# season_num             0
# time_of_day            0
# dtype: int64

# %%
X_train_p2 = train_set_p2.drop('rideable_type', axis=1)
y_train_p2 = train_set_p2['rideable_type'].copy()

# %% [markdown]
# Class Imbalance

# %%
from collections import Counter
from imblearn.under_sampling import RandomUnderSampler
rus = RandomUnderSampler(random_state=0)

X_train_p2, y_train_p2 = rus.fit_resample(X_train_p2, y_train_p2)

# %% [markdown]
# Pipeline

# %%
X_train_p2
# Out:
#        start_station_id  member_casual             distance  intra  \
# 0                    79              0   0.7495877412392384      0
# 1                     1              0                  0.0      0
# 2                    33              0   3.0257739258365133      0
# 3                    33              1   0.8297759871467439      0
# 4                    79              1   0.8873286951646564      0
# ...                 ...            ...                  ...    ...
# 45169                 2              0   1.5564652033904733      0
# 45170                33              1    1.409124270662168      0
# 45171                22              1  0.40622353685465457      0
# 45172                 4              0   1.3686253750214619      1
# 45173                20              0   1.5106211119892299      1
#
#        duration_secs  season_num  time_of_day
# 0              549.0           4            4
# 1              639.0           3            1
# 2              682.0           4            1
# 3              354.0           4            3
# 4              221.0           1            1
# ...              ...         ...          ...
# 45169          370.0           2            1
# 45170          345.0           2            5
# 45171          124.0           2            3
# 45172          594.0           2            5
# 45173          403.0           2            1
#
# [45174 rows x 7 columns]

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer


num_pipeline = Pipeline([
        ('imp', IterativeImputer()),
        ('std_scaler', StandardScaler()),
    ])

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder

num_attribs = ['distance', 'duration_secs']
cat_attribs = ['member_casual', 'time_of_day', 'season_num', 'intra', 'start_station_id']

preprocessor = ColumnTransformer([
        ('num', num_pipeline, num_attribs),
        ('cat', OneHotEncoder(handle_unknown='ignore'), cat_attribs),
    ])

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder

clf = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('classifier', RandomForestClassifier(random_state=35))
    ]
)

param_grid = [
    {'classifier__n_estimators': [50, 100]},
  ]

grid_search = GridSearchCV(clf, param_grid, cv=2)
grid_search.fit(X_train_p2, y_train_p2)
# Out:
# GridSearchCV(cv=2,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imp',
#                                                                                           IterativeImputer()),
#                                                                                          ('std_scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['distance',
#                                                                           'duration_secs']),
#                                                                         ('cat',
#                                                                          OneHotEncoder(handle_unknown='ignore'),
#                                                                          ['member_casual',
#                                                                           'time_of_day',
#                                                                           'season_num',
#                                                                           'intra',
#                                                                           'start_station_id'])])),
#                                        ('classifier',
#                                         RandomForestClassifier(random_state=35))]),
#              param_grid=[{'classifier__n_estimators': [50, 100]}])

# %% [markdown]
# Test set - doing exactly as the train dataset

# %% [markdown]
# Drop duplicated rows

# %%
dups = test_set_p2.duplicated()
dups.any()
# Out:
# True

# %%
test_set_p2.drop_duplicates(inplace=True)

# %% [markdown]
# Check if there are null values, (impute during pipeline just like train sets)

# %%
test_set_p2.isnull().sum()
# Out:
# rideable_type         0
# start_station_id      0
# member_casual         0
# distance            547
# intra                 0
# duration_secs         0
# season_num            0
# time_of_day           0
# dtype: int64

# %% [markdown]
# Split X and y

# %%
X_test = test_set_p2.drop('rideable_type', axis=1)
y_test = test_set_p2['rideable_type'].copy()

# %% [markdown]
# Model performance

# %%
from sklearn.metrics import mean_squared_error, confusion_matrix, classification_report, ConfusionMatrixDisplay
final_model = grid_search.best_estimator_

#grid_search.score(X_test, y_test)

print(classification_report(y_test, grid_search.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.81      0.88    115462
#            1       0.51      0.66      0.57     27742
#            2       0.28      0.85      0.42      3847
#
#     accuracy                           0.79    147051
#    macro avg       0.58      0.77      0.62    147051
# weighted avg       0.85      0.79      0.81    147051

# %% [markdown]
# ### Part 2: Classification Question 1

# %% [markdown]
# Based on the time spent, start station, end station, and distance, can we classify the user type and bike type (dock, electric, manual)?

# %% [markdown]
# ### Part 3: Classification Question 2

# %% [markdown]
# Based on predictive analysis, can we predict the length of trip and time of day (e.g. commuting hours, late nights, etc.)?

# %% [markdown]
# The above predictive and classification analysis will allow the NYC bike program stakeholders to predict and understand how riders are using their bikes. Based off of this information, they can create user personas and targeted advertising campaigns to grow ridership. This will facilitate a more efficient use of advertising dollars for the expansion.

# %% [markdown]
# NOtes: trips intra/inter neighborhods, pay atention to perf variables(falsepos/false neg)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=6751d308-8904-49e9-ab76-ff469d35696c' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
